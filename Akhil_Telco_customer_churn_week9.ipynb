# %% [markdown]
# # **INTRODUCTION**

# %% [markdown]
# *The Telco Customer Churn dataset contains information about a fictional telecommunications company that provided home phone and Internet services to 7,043 customers during the third quarter. It shows which customers have left, stayed, or signed up for their service. Some important demographic information is included for each customer, along with a satisfaction score, churn score, and customer lifetime value (CLTV) metrics.*

# %% [markdown]
# **Variables used in the dataset :**
#
# 1. **CustomerID:** A unique ID that identifies each customer.
#
# 2. **Count:** A value used in reporting/dashboarding to sum up the number of customers in a filtered set.
#
# 3.	**Country:** The country of the customer’s primary residence.
#
# 4.	**State:** The state of the customer’s primary residence.
#
# 5.	**City:** The city of the customer’s primary residence.
#
# 6.	**Zip Code:** The zip code of the customer’s primary residence.
#
# 7.	**Lat Long:** The combined latitude and longitude of the customer’s primary residence.
#
# 8.	**Latitude:** The latitude of the customer’s primary residence.
#
# 9.	**Longitude:** The longitude of the customer’s primary residence.
#
# 10.	**Gender:** The customer’s gender: Male, Female
#
# 11.	**Senior Citizen:** Indicates if the customer is 65 or older: Yes, No
#
# 12.	**Partner:** Indicate if the customer has a partner: Yes, No
#
# 13.	**Dependents:** Indicates if the customer lives with any dependents: Yes, No. Dependents could be children, parents, grandparents, etc.
#
# 14.	**Tenure Months:** Indicates the total amount of months that the customer has been with the company by the end of the quarter specified above.
#
# 15.	**Phone Service:** Indicates if the customer subscribes to home phone service with the company: Yes, No
#
# 16.	**Multiple Lines:** Indicates if the customer subscribes to multiple telephone lines with the company: Yes, No
#
# 17.	**Internet Service:** Indicates if the customer subscribes to Internet service with the company: No, DSL, Fiber Optic, Cable.
#
# 18.	**Online Security:** Indicates if the customer subscribes to an additional online security service provided by the company: Yes, No
#
# 19.	**Online Backup:** Indicates if the customer subscribes to an additional online backup service provided by the company: Yes, No
#
# 20.	**Device Protection:** Indicates if the customer subscribes to an additional device protection plan for their Internet equipment provided by the company: Yes, No
#
# 21.	**Tech Support:** Indicates if the customer subscribes to an additional technical support plan from the company with reduced wait times: Yes, No
#
# 22.	**Streaming TV:** Indicates if the customer uses their Internet service to stream television programming from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# 23.	**Streaming Movies:** Indicates if the customer uses their Internet service to stream movies from a third party provider: Yes, No. The company does not charge an additional fee for this service.
#
# 24.	**Contract:** Indicates the customer’s current contract type: Month-to-Month, One Year, Two Year.
#
# 25.	**Paperless Billing:** Indicates if the customer has chosen paperless billing: Yes, No
#
# 26.	**Payment Method:** Indicates how the customer pays their bill: Bank Withdrawal, Credit Card, Mailed Check
#
# 27.	**Monthly Charge:** Indicates the customer’s current total monthly charge for all their services from the company.
#
# 28.	**Total Charges:** Indicates the customer’s total charges, calculated to the end of the quarter specified above.
#
# 29.	**Churn Label:** Yes = the customer left the company this quarter. No = the customer remained with the company. Directly related to Churn Value.
#
# 30.	**Churn Value:** 1 = the customer left the company this quarter. 0 = the customer remained with the company. Directly related to Churn Label.
#
# 31.	**Churn Score:** A value from 0-100 that is calculated using the predictive tool IBM SPSS Modeler. The model incorporates multiple factors known to cause churn. The higher the score, the more likely the customer will churn.
#
# 32.	**CLTV:** Customer Lifetime Value. A predicted CLTV is calculated using corporate formulas and existing data. The higher the value, the more valuable the customer. High value customers should be monitored for churn.
#
# 33.	**Churn Reason:** A customer’s specific reason for leaving the company. Directly related to Churn Category.

# %% [markdown]
# **Explanation of Dataset:**
#
# This dataset consist of 7043 observations with 33 variables, all the columns are self explanotary but there is one column.
#
# CLTV -  CLTV is also know as combined loan-to-value means, it a ratio of all secured loans on a property to the value of a property.

# %% [markdown]
# ## **Importing the needed libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Q1: Please read the file and explain data types statistically as well as how python is reading it. Please let us know if any data type is read wrong.**

# %% [markdown]
# ### Reading the dataset

# %%
rawData = pd.read_excel("Telco_customer_churn.xlsx")

# %%
#Checking the first 5 rows
rawData.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK    1.0  United States  California  Los Angeles   90003.0
# 1  9237-HQITU    1.0  United States  California  Los Angeles   90005.0
# 2  9305-CDSKC    1.0  United States  California  Los Angeles   90006.0
# 3  7892-POOKP    1.0  United States  California  Los Angeles   90010.0
# 4  0280-XJGEX    1.0  United States  California  Los Angeles   90015.0
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %% [markdown]
# ## **Data Cleaning and Fixing the dataset**

# %% [markdown]
# ### Checking the duplicate data in database

# %%
rawData.duplicated().sum()
#There is no duplicate data in dataset
# Out:
# 0

# %% [markdown]
# ### Checking the Null Value in dataset

# %%
rawData.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %% [markdown]
# There is 5174 null values in the the column churn Reason.

# %% [markdown]
# 1. As in Churn Reason column there are lot of null value can delete them , it may have more impact on total dataset so , going to fill the null value.
# 2. As Churn Reason is a nominal level value so filling the data with mode.

# %%
#As Churn Reason is is a categorical data can't use mean or median,can only use mode so, using mode to fill the null values.
#Replacing the null value i Churn Reason  column

rawData['Churn Reason'] = rawData['Churn Reason'].fillna(rawData['Churn Reason'].mode().iloc[0])  
# basically Replace missing values with the most frequent value in churn reason column mode() can given morethen one output so taking 1st value using iloc[0]

# %% [markdown]
# ### Lets check the info of dataset

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   float64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   float64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   float64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# From the above data there is no null values but , python is reading the some columns wrongly
# 1. Zip code
# 2. Total Charges
# 3. Churn Value
# 4. Churn Score
# 5. CLTV
# 6. Count

# %% [markdown]
# ### Lets change the Datatypes of those columns

# %%
#Changing the Total charges datatype from Sting to float 
rawData["Total Charges"] = pd.to_numeric(rawData["Total Charges"],errors = 'coerce')

# %%
#Change the Count ,Zip Code, Churn Value , Churn Score, CLTV datatype from float to int
rawData['Count'] = rawData['Count'].astype('int64')
rawData['Zip Code'] = rawData['Zip Code'].astype('int64')
rawData['Churn Value'] = rawData['Churn Value'].astype('int64')
rawData['Churn Score'] = rawData['Churn Score'].astype('int64')
rawData['CLTV'] = rawData['Zip Code'].astype('int64')

# %%
#lets check if those datatype are changed or not
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   float64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %% [markdown]
# From the above result the Zip code, Total Charges, Churn Value, Churn Score, CLTV,Count  column datatype is changed to float and int.

# %% [markdown]
# **Python reading data:**
#
# From the above result found that :-
#
# 1. Python is reading Customer ID , Country ,State , City ,Lat long ,Gender , Senior Citizien , Partner , Dependents , Phone Service , Multiple Lines , Internet Service , Online Service , Online Backup , Device protection , Tech Support , Streaming Tv , Streaming movies , Contract , Paperless Billing , Payment Methods, Churn Label , Churn reason as **Sting variable**.
#
# 2. Python is reading latitude , longitude , Monthly charges ,Total Charges as **Float variables**.
#
# 3. python is reading the Count ,Zip code,Churn value , Churn Score , CLTV as **integer**

# %% [markdown]
# **Statastical Representation of Data:**
# Through the satatasticla approch:-  the columns are devided into Nominal , Discret , Continues , Interval level data.
#
# 1. Nominal level :- Customer ID , Country , State , City , Lat Long , Gender ,Senior Citizon , Partner , Dependents , Phone Service , Multiple Lines , Internet Service , Online Service , Online Backup , Device protection , Tech Support , Streaming Tv , Streaming movies , Paperless Billing , Python Methods ,, Churn Label , Churn reason,Contract.
#
# 2. Discreat level :- Count , Tenure Month, Churn Score, CLTV ,Churn Value.
#
# 3. Continues level :-Monthly Charges , Total Charges.
#
# 4. Intervel level : Zip Code,Latitude , Longitude.

# %% [markdown]
# # EDA(Exploratory data analysis):

# %% [markdown]
# ## **Q2: Please apply appropriate statistical measures using python based on data types.**

# %%
Nominal = ['CustomerID' , 'Country' , 'State' , 'City' , 'Lat Long' , 'Gender' ,'Senior Citizen' , 'Partner' , 'Dependents' , 
           'Phone Service' , 'Multiple Lines' , 'Internet Service' , 'Online Security' , 'Online Backup' , 'Device Protection' , 'Tech Support' , 
           'Streaming TV' , 'Streaming Movies','Contract' , 'Paperless Billing' , 'Payment Method' , 'Churn Label' , 'Churn Reason']
Discret =['Tenure Months','Count' , 'Churn Score', 'CLTV' ,'Churn Value']

Continues  = ['Monthly Charges' , 'Total Charges']

Intervel= ['Zip Code','Latitude','Longitude']

count =0;

print("*************************************")
print("Stastical Measures for Nominal Data")
print("*************************************")
print(" ")
for i in Nominal:
  print(f"Mode of {i} = {rawData[i].mode().to_string().split()}")
  
  print("--------------------------------------------------")
  print("\n")

print('*************************************')
print("Stastical Measures for Discret Data")
print('*************************************')
print(" ")
for i in Discret:
  print(f"Mean of {i} = {rawData[i].mean()}")
  print(f"Mediam of {i} = {rawData[i].median()}")
  print(f"Mode of {i} = {rawData[i].mode()}")
  print(f"Standed deviation of {i} = {rawData[i].std()}")
  print(f"Variance of {i} = {rawData[i].var()}")
  print("--------------------------------------------------")
  print("\n")

  print('*************************************')
print("Stastical Measures for Continues Data")
print('*************************************')
print(" ")
for i in Continues:
  print(f"Mean of {i} = {rawData[i].mean()}")
  print(f"Mediam of {i} = {rawData[i].median()}")
  print(f"Mode of {i} = {rawData[i].mode()}")
  print(f"Standed deviation of {i} = {rawData[i].std()}")
  print(f"Variance of {i} = {rawData[i].var()}")
  print("--------------------------------------------------")
  print("\n")

print('*************************************')
print("Stastical Measures for Intervel Data")
print('*************************************')
print(" ")
for i in Intervel:
  print(f"Mean of {i} = {rawData[i].mean()}")
  print(f"Mediam of {i} = {rawData[i].median()}")
  print(f"Mode of {i} = {rawData[i].mode().to_string().split()}")
  print(f"Standed deviation of {i} = {rawData[i].std()}")
  print(f"Variance of {i} = {rawData[i].var()}")
  print("--------------------------------------------------")
  print("\n")
# Out:
# *************************************
# Stastical Measures for Nominal Data
# *************************************
#
# ...

# %% [markdown]
# ### standard deviation, variance, IQR, min, max  for Discret,Continues,Intervel

# %%
rawData.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Total Charges  Churn Value  Churn Score          CLTV
# count      7043.000000    7032.000000  7043.000000  7043.000000   7043.000000
# mean         64.761692    2283.300441     0.265370    58.699418  93521.964646
# std          30.090047    2266.771362     0.441561    21.525131   1865.794555
# ...

# %% [markdown]
# **from the top table std is standed deviation = std , max = max , min = min , Q1 = 25% ,Q2= 50% ,Q3 = 75% IQR = Q3-Q1**

# %%
#Calculating the IQR
alldata = ['Count','Zip Code','Latitude','Longitude','Tenure Months','Monthly Charges','Total Charges','Churn Value','Churn Score','CLTV']

print("Calculating the IQR")
for i in alldata:
  print(f"{i} IQR  = {rawData[i].quantile(0.75) - rawData[i].quantile(0.25)}")
# Out:
# Calculating the IQR
# Count IQR  = 0.0
# Zip Code IQR  = 3249.0
# Latitude IQR  = 4.193953999999998
# Longitude IQR  = 3.77217499999999
# Tenure Months IQR  = 46.0
# Monthly Charges IQR  = 54.349999999999994
# Total Charges IQR  = 3393.2875000000004
# Churn Value IQR  = 1.0
# Churn Score IQR  = 35.0
# CLTV IQR  = 3249.0

# %% [markdown]
# **While going forword we just need 10 columns out of 33 columns to slove rest all question, they are *CustomerID,City , Zip Code,Gender , Senior Citizen, Tenure Month, Payment Method, Monthly Charges, Total Charges ,Churn Score* So deleting the rest 23 columns to avoid the display conflict**

# %%
#Extracting only above mentioned columns
df = rawData.loc[:,rawData.columns.intersection(['CustomerID','City','Zip Code','Gender',
                                            'Senior Citizen','Tenure Months','Payment Method',
                                            'Monthly Charges','Total Charges','Churn Score'])]     #Intersection will extract the needed columns data

# %%
#lets check the those colums firt 5 rows
df.head()
# Out:
#    CustomerID         City  Zip Code  Gender Senior Citizen  Tenure Months  \
# 0  3668-QPYBK  Los Angeles     90003    Male             No            2.0
# 1  9237-HQITU  Los Angeles     90005  Female             No            2.0
# 2  9305-CDSKC  Los Angeles     90006  Female             No            8.0
# 3  7892-POOKP  Los Angeles     90010  Female             No           28.0
# 4  0280-XJGEX  Los Angeles     90015    Male             No           49.0
#
#               Payment Method  Monthly Charges  Total Charges  Churn Score
# 0               Mailed check            53.85         108.15           86
# 1           Electronic check            70.70         151.65           67
# 2           Electronic check            99.65         820.50           86
# 3           Electronic check           104.80        3046.05           84
# 4  Bank transfer (automatic)           103.70        5036.30           89

# %% [markdown]
# ## **Q3: What is the percentage of females and senior citizens in this data set? Please create appropriate plots and explain the plots.**

# %%
plt.figure(figsize=(12,5)) #setting the chat size 
plt.pie(rawData['Gender'].value_counts(),labels=rawData['Gender'].unique(), autopct='%.2f%%') 
plt.title("Figure 1:Percentage of Female and Senior Citizen")
plt.show()

# %%
rawData['Gender'].value_counts()
# Out:
# Male      3555
# Female    3488
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(12,5)) #setting the chat size 
plt.pie(rawData['Senior Citizen'].value_counts(),labels=rawData['Senior Citizen'].unique(), autopct='%.2f%%') 
plt.title("Figure 1:Percentage of Female and Senior Citizen")
plt.show()

# %%
rawData['Senior Citizen'].value_counts()
# Out:
# No     5901
# Yes    1142
# Name: Senior Citizen, dtype: int64

# %% [markdown]
# **Observation:**
# 1. Fom the above plot the Female percentage(49.52%) is more than Senior Citizen percentage(16.21%).

# %% [markdown]
# ## **Q4) Please create an appropriate plot to examine the distribution of the tenure month column and explain the distribution. Based on distribution, perform appropriate statistical measures. Please also explain if the variable is symmetric or skewed. Please calculate it. Explain everything as asked.**

# %%
#Ploting the Distribution plot to the tenure month column
sns.distplot(df['Tenure Months'],bins=10) #Each bin is plotted as a bar whose height corresponds to how many data points are in that bin
plt.title("Distribution of the Tenure Month")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Distribution of the Tenure Month')

# %%
#Calculating the stastical measures 
print(f"mean of Tenure Month is {df['Tenure Months'].mean()}")
print(f"Mode of Tenure Month is {df['Tenure Months'].mode()}")
print(f"Median of Tenure Month is {df['Tenure Months'].median()}")
# Out:
# mean of Tenure Month is 32.37114865824223
# Mode of Tenure Month is 0    1.0
# dtype: float64
# Median of Tenure Month is 29.0

# %%
#Calculating the skewness 
#need a libriary to calculate the skewness  - scipy from that importing skew
from scipy.stats import skew
print(f"Skewnees of Tenure Months is {skew(df['Tenure Months'])}")
# Out:
# Skewnees of Tenure Months is 0.2394887299846216

# %% [markdown]
# **Observation:**
# 1. From the Skwness value 0.23 it can be conclude that it is in fairly Symmetrical distribution , if the skewness value falls under -0.5 to 0.5 then it is called fairly symmetrical distribution.
# 2. BY looking the above Plot it have Right-Skewed Distribution.

# %% [markdown]
# ## **Q5: Please convert all binary columns into 0 and 1 using appropriate programming constructs, not one by one.**

# %%
#As this questuion needed the all 33 columns data so taking that raw_data variable
#Extracting the binary columns into another variable

binary =  rawData.loc[:,rawData.columns.intersection(['Gender','Senior Citizen','Partner','Dependents','Phone Service','Multiple Lines','Online Security','Online Backup',
                                                      'Device Protection','Tech Support','Streaming TV','Streaming Movies','Paperless Billing','Churn Label'])]

# %%
#lets check all the columns are there are not.
binary.head()
# Out:
#    Gender Senior Citizen Partner Dependents Phone Service Multiple Lines  \
# 0    Male             No      No         No           Yes             No
# 1  Female             No      No        Yes           Yes             No
# 2  Female             No      No        Yes           Yes            Yes
# 3  Female             No     Yes        Yes           Yes            Yes
# 4    Male             No      No        Yes           Yes            Yes
#
#   Online Security Online Backup Device Protection Tech Support Streaming TV  \
# 0             Yes           Yes                No           No           No
# 1              No            No                No           No           No
# 2              No            No               Yes           No          Yes
# 3              No            No               Yes          Yes          Yes
# 4              No           Yes               Yes           No          Yes
#
#   Streaming Movies Paperless Billing Churn Label
# ...

# %%
#checking the unique values for binary columns 
for i in binary:
  print(f"{i} have {binary[i].unique()}")
# Out:
# Gender have ['Male' 'Female']
# Senior Citizen have ['No' 'Yes']
# Partner have ['No' 'Yes']
# Dependents have ['No' 'Yes']
# Phone Service have ['Yes' 'No']
# Multiple Lines have ['No' 'Yes' 'No phone service']
# Online Security have ['Yes' 'No' 'No internet service']
# Online Backup have ['Yes' 'No' 'No internet service']
# Device Protection have ['No' 'Yes' 'No internet service']
# Tech Support have ['No' 'Yes' 'No internet service']
# Streaming TV have ['No' 'Yes' 'No internet service']
# Streaming Movies have ['No' 'Yes' 'No internet service']
# Paperless Billing have ['Yes' 'No']
# Churn Label have ['Yes' 'No']

# %%
#lets start conversion part.
#by analysing the data  there are 2 type of data  1) male , female 2) yes , no 
# convertion male as 1 and female as 0 and yes as 1 and no as 0

binary = binary.replace(['Male','Female','Yes','No','No internet service','No phone service'],['1','0','1','0','0','0'])

# %%
#lets check all the columns are changed or not 
binary.head()
# Out:
#   Gender Senior Citizen Partner Dependents Phone Service Multiple Lines  \
# 0      1              0       0          0             1              0
# 1      0              0       0          1             1              0
# 2      0              0       0          1             1              1
# 3      0              0       1          1             1              1
# 4      1              0       0          1             1              1
#
#   Online Security Online Backup Device Protection Tech Support Streaming TV  \
# 0               1             1                 0            0            0
# 1               0             0                 0            0            0
# 2               0             0                 1            0            1
# 3               0             0                 1            1            1
# 4               0             1                 1            0            1
#
#   Streaming Movies Paperless Billing Churn Label
# ...

# %%
binary.tail()
# Out:
#      Gender Senior Citizen Partner Dependents Phone Service Multiple Lines  \
# 7038      0              0       0          0             1              0
# 7039      1              0       1          1             1              1
# 7040      0              0       1          1             1              1
# 7041      0              0       1          1             0              0
# 7042      1              0       0          0             1              0
#
#      Online Security Online Backup Device Protection Tech Support  \
# 7038               0             0                 0            0
# 7039               1             0                 1            1
# 7040               0             1                 1            0
# 7041               1             0                 0            0
# 7042               1             0                 1            1
#
#      Streaming TV Streaming Movies Paperless Billing Churn Label
# ...

# %%
#Now the binary tables are changed to 0 and 1 but the columns datatype is still string , so converting it in to int.
conv_Binary= binary.astype('int64')

# %%
conv_Binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             7043 non-null   int64
#  1   Senior Citizen     7043 non-null   int64
#  2   Partner            7043 non-null   int64
#  3   Dependents         7043 non-null   int64
#  4   Phone Service      7043 non-null   int64
#  5   Multiple Lines     7043 non-null   int64
#  6   Online Security    7043 non-null   int64
#  7   Online Backup      7043 non-null   int64
#  8   Device Protection  7043 non-null   int64
#  9   Tech Support       7043 non-null   int64
#  10  Streaming TV       7043 non-null   int64
#  11  Streaming Movies   7043 non-null   int64
#  12  Paperless Billing  7043 non-null   int64
#  13  Churn Label        7043 non-null   int64
# dtypes: int64(14)
# memory usage: 770.5 KB

# %% [markdown]
# **Now all columns are converted into pure binary columns**

# %% [markdown]
# ## .**Q6: Please examine the distribution of monthly charges between males and females using box plots. Please explain the results also.**

# %%
sns.boxplot(x='Gender',y='Monthly Charges',data=df) #xaxis is Gender and yaxis is gross income
plt.title("Distribution of monthly between males and females")
# Out:
# Text(0.5, 1.0, 'Distribution of monthly between males and females')

# %% [markdown]
# **Observation:**
# 1. As per above plot , both male and female graphs have Right skew or we can tell it as positive skew.

# %% [markdown]
# ## **Q7: Please find what is the minimum total charges for Los Angeles city. Please find which zip code has the maximum total charges.**

# %%
print(f"The Minimum total charges for Los Angeles city: {df[df['City'] == 'Los Angeles'].min()['Total Charges']}")

zip_code =(df[df['Total Charges'] == df['Total Charges'].max()]['Zip Code']).to_string().split(" ")[4]

print(f"The zip code which have maximum total charges is : {zip_code}")
# Out:
# The Minimum total charges for Los Angeles city: 18.8
# The zip code which have maximum total charges is : 95519

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       7043 non-null   object
#  1   City             7043 non-null   object
#  2   Zip Code         7043 non-null   int64
#  3   Gender           7043 non-null   object
#  4   Senior Citizen   7043 non-null   object
#  5   Tenure Months    7043 non-null   float64
#  6   Payment Method   7043 non-null   object
#  7   Monthly Charges  7043 non-null   float64
#  8   Total Charges    7032 non-null   float64
#  9   Churn Score      7043 non-null   int64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 550.4+ KB

# %% [markdown]
# ## **Q8: Please find which payment method has the highest churn score and which has the lowest churn score.**

# %%
raw_max = df[df['Churn Score'] == df['Churn Score'].max()]['Payment Method'].drop_duplicates().to_string().split() 
#the maximum value of churn score is 100 with 100 there are lot of rows , in paymet there is only 4 types so from that data deleting  duplicate data and 
#keeping only single instance of payment types 
maximum = [raw_max[1]+" "+raw_max[2],raw_max[4]+" "+raw_max[5]+" "+raw_max[6],raw_max[8]+" "+raw_max[9],raw_max[11]+" "+raw_max[12]+" "+raw_max[13]]
#By using maximum list creating the structured data.
minimum = df[df['Churn Score'] == df['Churn Score'].min()]['Payment Method'].to_string().split()

print(f"The maximum Churn Score is {df[df['Churn Score'] == df['Churn Score'].max()]['Churn Score'].unique()}")
print("The Payment method which have maximum Churan score is")
for i in maximum:
  print(i)
print("------------------------------------------------------------")
print(f"The maximum Churn Score is {df[df['Churn Score'] == df['Churn Score'].min()]['Churn Score'].unique()}")
print("The Payment method which have minimum Churan score is")
print(minimum[1]+" "+minimum[2]+" "+minimum[3])
# Out:
# The maximum Churn Score is [100]
# The Payment method which have maximum Churan score is
# Electronic check
# Bank transfer (automatic)
# Mailed check
# Credit card (automatic)
# ------------------------------------------------------------
# The maximum Churn Score is [5]
# The Payment method which have minimum Churan score is
# Credit card (automatic)

# %% [markdown]
# ## **Q9: Please create an appropriate plot to check the count of payment methods and explain it.**

# %%
plt.figure(figsize=(10,5)) #setting the chat size 
sns.countplot(x="Payment Method", data=df)
plt.ylabel('Total count of Payment Methods')
plt.title("Count of Payment Method")
# Out:
# Text(0.5, 1.0, 'Count of Payment Method')

# %%
df['Payment Method'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: Payment Method, dtype: int64

# %% [markdown]
# **Observation:**
# 1. The Customers are using ***Electronic check*** payment method more then other payment menthods
# 2. Least using payment method is ***credit card*** , however when we compare ***Bank transfer*** and ***credit card*** there is only slight change in numbers and change can we countable.

# %% [markdown]
# ## **Q10: Please create an appropriate plot to see the relationship between monthly charges and total charges.**

# %%
plt.figure(figsize=(9,10)) #setting the chat size 
pt = sns.scatterplot(x='Monthly Charges', y='Total Charges',data=df)

# %% [markdown]
# **Observation:**
# 1. By the above scatterplot there is a Positive correlation between Total charges and Monthly Charges.

# %% [markdown]
# ## **Conclusion:**

# %% [markdown]
# The importance of this type of research in the telecom market is to help companies make more profit. It has become known that predicting churn is one of the most important sources of income to telecom companies.
#
# There are some identifiers:
# 1. The count of female are more than the count of seniour citizen
# 2. The monthly charges of male and females are similar in number
# 3. There is positive corelation between total charge and monthlu charge
# 4. Most of customers are using Electronic check to pay.
